# %% [markdown]
# # Partition Sublattice Checks

# %% [markdown]
# This notebook will check whether the bond lattices of various common graph types are sublattices of the partition lattice. Since the bond join is the same as the partition join, we only need to check that the bond lattice is closed under the partition meet. This is precisely what the function partition_sublattice_checker() does. We present the findings in Table $1$ in the report.

# %%
import networkx as nx
from Modules.bond_finders import *
from Modules.lattice_machinery import *

# %% [markdown]
# ## 1. Complete Graphs

# %%
# Loop over number of vertices d
for i in range(1, 9):

    # Form graph with specified number of vertices
    graph = nx.complete_graph(i)

    # Check whether sublattice of partition lattice
    verdict = partition_sublattice_checker(graph, walk_bond_finder)

    print(f"{i}-vertex complete graph's bond lattice is a sublattice of the partition lattice: {verdict}")
# Out:
# 1-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 2-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 3-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 4-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 5-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 6-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 7-vertex complete graph's bond lattice is a sublattice of the partition lattice: True
# 8-vertex complete graph's bond lattice is a sublattice of the partition lattice: True

# %% [markdown]
# ## 2. Path Graphs

# %%
# Loop over number of vertices d
for i in range(1, 9):

    # Form graph with specified number of vertices
    graph = nx.path_graph(i)

    # Check whether sublattice of partition lattice
    verdict = partition_sublattice_checker(graph, walk_bond_finder)
    print(f"{i}-vertex path graph's bond lattice is a sublattice of the partition lattice: {verdict}")
# Out:
# 1-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 2-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 3-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 4-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 5-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 6-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 7-vertex path graph's bond lattice is a sublattice of the partition lattice: True
# 8-vertex path graph's bond lattice is a sublattice of the partition lattice: True

# %% [markdown]
# ## 3. Star Graphs

# %%
# Loop over number of vertices d
for i in range(0, 8):

    # Form graph with specified number of vertices
    graph = nx.star_graph(i)

    # Check whether sublattice of partition lattice
    verdict = partition_sublattice_checker(graph, walk_bond_finder)
    print(f"{i}-vertex star graph's bond lattice is a sublattice of the partition lattice: {verdict}")
# Out:
# 0-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 1-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 2-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 3-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 4-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 5-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 6-vertex star graph's bond lattice is a sublattice of the partition lattice: True
# 7-vertex star graph's bond lattice is a sublattice of the partition lattice: True

# %% [markdown]
# ## 4. Wheel Graphs

# %%
# Loop over number of vertices d
for i in range(1, 9):

    # Form graph with specified number of vertices
    graph = nx.wheel_graph(i)

    # Check whether sublattice of partition lattice
    verdict = partition_sublattice_checker(graph, walk_bond_finder)

    print(f"{i}-vertex wheel graph's bond lattice is a sublattice of the partition lattice: {verdict}")
# Out:
# 1-vertex wheel graph's bond lattice is a sublattice of the partition lattice: True
# 2-vertex wheel graph's bond lattice is a sublattice of the partition lattice: True
# 3-vertex wheel graph's bond lattice is a sublattice of the partition lattice: True
# 4-vertex wheel graph's bond lattice is a sublattice of the partition lattice: True
# 5-vertex wheel graph's bond lattice is a sublattice of the partition lattice: False
# 6-vertex wheel graph's bond lattice is a sublattice of the partition lattice: False
# 7-vertex wheel graph's bond lattice is a sublattice of the partition lattice: False
# 8-vertex wheel graph's bond lattice is a sublattice of the partition lattice: False

# %% [markdown]
# ## 5. Cycle Graphs

# %%
# List to store sublattice verdicts
verdicts = []

# Loop over number of vertices d
for i in range(1, 9):

    # Form graph with specified number of vertices
    graph = nx.cycle_graph(i)

    # Check whether sublattice of partition lattice
    verdict = partition_sublattice_checker(graph, walk_bond_finder)

    print(f"{i}-vertex cycle graph's bond lattice is a sublattice of the partition lattice: {verdict}")
# Out:
# 1-vertex cycle graph's bond lattice is a sublattice of the partition lattice: True
# 2-vertex cycle graph's bond lattice is a sublattice of the partition lattice: True
# 3-vertex cycle graph's bond lattice is a sublattice of the partition lattice: True
# 4-vertex cycle graph's bond lattice is a sublattice of the partition lattice: False
# 5-vertex cycle graph's bond lattice is a sublattice of the partition lattice: False
# 6-vertex cycle graph's bond lattice is a sublattice of the partition lattice: False
# 7-vertex cycle graph's bond lattice is a sublattice of the partition lattice: False
# 8-vertex cycle graph's bond lattice is a sublattice of the partition lattice: False
